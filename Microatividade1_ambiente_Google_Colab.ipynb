# %% [markdown]
# <a href="https://colab.research.google.com/github/Futureforworld/MP-N4/blob/branch/Microatividade1_ambiente_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá, este é meu primeiro código no Google Colab!")
# Out:
# Olá, este é meu primeiro código no Google Colab!

# %%
a = 10
b = 20
soma = a + b
print("A soma de a + b é:", soma)
# Out:
# A soma de a + b é: 30

# %% [markdown]
# # Este é um bloco de texto
# **Aqui podemos escrever descrições ou explicações sobre o código.**
